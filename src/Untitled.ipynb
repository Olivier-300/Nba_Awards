# %%
import pandas as pd
import os
import logging

# %%
def setup_logging():
    logging.basicConfig(
        filename='files/processing.log', 
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )

# %%
input_file = 'players_stats_regular.xlsx'

# %%
output_file = 'processed_players_stats_regular.xlsx'

# %%
mvp_file = 'mvp_winners.xlsx'

# %%
team_file = "team_standings.xlsx"

# %%
include_mvp=True
include_w_pct=True

# %%
data = pd.read_excel(f'files/{input_file}')

# %%
data
# Out:
#        Season       Season_Type  PLAYER_ID  RANK           PLAYER     TEAM_ID  \
# 0     2013-14  Regular%20Season     201142     1     Kevin Durant  1610612760
# 1     2013-14  Regular%20Season       2546     2  Carmelo Anthony  1610612752
# 2     2013-14  Regular%20Season       2544     3     LeBron James  1610612748
# 3     2013-14  Regular%20Season     201567     4       Kevin Love  1610612750
# 4     2013-14  Regular%20Season     201935     5     James Harden  1610612745
# ...       ...               ...        ...   ...              ...         ...
# 3033  2024-25  Regular%20Season    1642345   244     Oso Ighodaro  1610612756
# 3034  2024-25  Regular%20Season     201587   245    Nicolas Batum  1610612746
# 3035  2024-25  Regular%20Season    1641816   246     Hunter Tyson  1610612743
# 3036  2024-25  Regular%20Season    1630579   247     Jericho Sims  1610612749
# 3037  2024-25  Regular%20Season     203458   248         Alex Len  1610612747
#
# ...

# %%
data_cleaned['Season']
# Out:
# 0       0       2013-14\n1       2013-14\n2       2013...
# 1       0       2013-14\n1       2013-14\n2       2013...
# 2       0       2013-14\n1       2013-14\n2       2013...
# 3       0       2013-14\n1       2013-14\n2       2013...
# 4       0       2013-14\n1       2013-14\n2       2013...
#                               ...
# 3033    0       2013-14\n1       2013-14\n2       2013...
# 3034    0       2013-14\n1       2013-14\n2       2013...
# 3035    0       2013-14\n1       2013-14\n2       2013...
# 3036    0       2013-14\n1       2013-14\n2       2013...
# 3037    0       2013-14\n1       2013-14\n2       2013...
# Name: Season, Length: 3038, dtype: object
